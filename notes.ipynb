# %% [markdown]
# ## 07-07-2026

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## HTML Tags Reference
#
# #### Document Structure
# | Tag | Purpose |
# |-----|---------|
# | `<html>` | Root element |
# | `<head>` | Contains metadata |
# | `<body>` | Main content |
# | `<title>` | Page title |
# | `<meta>` | Metadata |
#
# #### Semantic Elements
# | Tag | Purpose |
# |-----|---------|
# | `<header>` | Header section |
# | `<nav>` | Navigation |
# | `<main>` | Main content |
# | `<article>` | Article content |
# | `<section>` | Section of content |
# | `<aside>` | Sidebar/related content |
# | `<footer>` | Footer section |
#
# #### Headings
# | Tag | Purpose |
# |-----|---------|
# | `<h1>` - `<h6>` | Headings (largest to smallest) |
#
# #### Text Formatting
# | Tag | Purpose |
# |-----|---------|
# | `<p>` | Paragraph |
# | `<a>` | Hyperlink |
# | `<strong>` | Strong importance (bold) |
# | `<em>` | Emphasis (italic) |
# | `<b>` | Bold text |
# | `<i>` | Italic text |
# | `<u>` | Underline |
# | `<br>` | Line break |
# | `<hr>` | Horizontal rule |
# | `<mark>` | Highlighted text |
# | `<small>` | Small text |
# | `<sub>` | Subscript |
# | `<sup>` | Superscript |
# | `<code>` | Code snippet |
# | `<blockquote>` | Block quotation |
# | `<pre>` | Preformatted text |
#
# #### Lists
# | Tag | Purpose |
# |-----|---------|
# | `<ul>` | Unordered list |
# | `<ol>` | Ordered list |
# | `<li>` | List item |
# | `<dl>` | Definition list |
# | `<dt>` | Definition term |
# | `<dd>` | Definition description |
#
# ## Media
# | Tag | Purpose |
# |-----|---------|
# | `<img>` | Image |
# | `<audio>` | Audio file |
# | `<video>` | Video file |
# | `<source>` | Media source |
# | `<figure>` | Self-contained illustration |
# | `<figcaption>` | Caption for figure |
#
# #### Tables
# | Tag | Purpose |
# |-----|---------|
# | `<table>` | Table container |
# | `<tr>` | Table row |
# | `<td>` | Table data cell |
# | `<th>` | Table header cell |
# | `<thead>` | Table header section |
# | `<tbody>` | Table body section |
# | `<tfoot>` | Table footer section |
# | `<caption>` | Table caption |
#
# #### Forms
# | Tag | Purpose |
# |-----|---------|
# | `<form>` | Form container |
# | `<input>` | Input field |
# | `<button>` | Button |
# | `<select>` | Dropdown list |
# | `<option>` | Dropdown option |
# | `<textarea>` | Multi-line text input |
# | `<label>` | Form label |
# | `<fieldset>` | Group form elements |
# | `<legend>` | Legend for fieldset |
#
# #### Grouping & Containers
# | Tag | Purpose |
# |-----|---------|
# | `<div>` | Generic container |
# | `<span>` | Inline container |
# | `<address>` | Contact information |
#
# #### Other
# | Tag | Purpose |
# |-----|---------|
# | `<iframe>` | Embedded frame |
# | `<script>` | JavaScript code |
# | `<style>` | CSS styles |
# | `<link>` | External resource |
# | `<time>` | Date/time |

# %% [markdown]
# #### CSS Specificity (power of selectors) -
# - Universal * --> 0
# - Element --> 1
# - class - can be used multiple times --> 10
# - id - can only be used once --> 100
# - inline --> 1000

# %% [markdown]
# #### Combinators
# - Descendant Selector (space) - selects all elements that are descendants of a specified element.
# - Child Selector (>) - selects all elements that are direct children of a specified element.
# - Adjacent Sibling Selector (+) - selects the element that is immediately after another specified element.
# - General Sibling Selector (~) - selects all elements that are siblings of a specified element.

# %% [markdown]
# ### Var vs Let vs Const
# - var is function scoped, let and const are block scoped
# - var can be re-declared and updated, let can be updated but not re-declared, const cannot be updated or re-declared
# - var is hoisted to the top of its scope and initialized with undefined, let and const are hoisted to the top of their scope but not initialized

# %% [markdown]
# ### Hoisting
# - Hoisting is a JavaScript mechanism where variables and function declarations are moved to the top of their containing scope during the compilation phase. This means that you can use variables and functions before they are declared in the code.
# - JS Property --> All traditional functions, var

# %% [markdown]
# ### Execution Context
# - JS Property --> All functions, var, let, const
# ### Execution Scope
# - The scope in which the execution context is active

# %% [markdown]
# ### IIFE (Immediately Invoked Function Expression)
# - They are functions that are executed immediately after they are defined. They are used to create a new scope and avoid polluting the global scope.
